# %%
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 18, 6  # that's default image size for this interactive session

from gc_turbulence import SingleLayerRun, AnalysisRun

# %%
# this is a simple single layer full depth run
single_layer_cache = '/home/eeaol/lab/data/flume2/main_data/cache/3mp0zhhn.hdf5'

# interesting two layer run with high amplitude wave
# r14_01_16c, h1=0.05, S=0.2
two_layer_cache = '/home/eeaol/lab/data/flume2/main_data/cache/3n8hfzme.hdf5'

# this is the corresponding run with no stratification
partial_cache = '/nfs/see-fs-02_users/eeaol/lab/data/flume2/main_data/cache/3n8hhght.hdf5'

# full_depth_run
r = SingleLayerRun(cache_path=single_layer_cache)

# two layer run
r2 = SingleLayerRun(cache_path=two_layer_cache)

# two layer run comparison
r2c = SingleLayerRun(cache_path=partial_cache)

# %%
rs = (slice(None), 50, slice(500, 2200))

# %%
contourf(r.t[rs], r.z[rs], r.u[rs] * 1000, levels=np.linspace(-110, 110))
cbar = colorbar()
cbar.set_label('streamwise velocity (mm / s)')
xlabel('time after lock release (s)')
ylabel('vertical (mm)')

# %%
contourf(r.t[rs], r.z[rs], r.w[rs] * 1000, levels=np.linspace(-40, 40))
cbar = colorbar()
cbar.set_label('vertical velocity (mm / s)')
xlabel('time after lock release (s)')
ylabel('vertical (mm)')

# %%
w_range = (-0.040, 0.040)                                                                                                                                        

bins = 300                                                                                                                                                    
bin_values = np.linspace(w_range[0], w_range[1], nbins)
hist_z_100 = np.array([np.histogram(z, range=w_range, bins=nbins, density=True)[0] for z in r.w[5:-15, 10:-10, 600:1400]])
heights = r.z[5:-15, 0, 0]
contourf(bin_values, heights, hist_z_100, levels=np.linspace(0, 100))

print r.t[0, 0, 600]
print r.t[0, 0, 1200]
xlabel('vertical velocity')
title('Vertical velocity distribution with height, time 36-44s')
# Out:
# 36.0
# 42.0

# %%
w_range = (-0.040, 0.040)                                                                                                                                        

bins = 300                                                                                                                                                    
bin_values = np.linspace(w_range[0], w_range[1], nbins)
r_shear = np.diff(r.w, axis=0)[5:-15, 10:-10, 600:1400]

hist_z_100 = np.array([np.histogram(z, range=w_range, bins=nbins, density=True)[0] for z in r_shear])
heights = r.z[5:-15, 0, 0]
contourf(bin_values, heights, hist_z_100, levels=np.linspace(0, 100))

print r.t[0, 0, 600]
print r.t[0, 0, 1200]
xlabel('vertical velocity')
title('Shear distribution with height, time 36-44s')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-68d3431b44f2> in <module>()
#       7 hist_z_100 = np.array([np.histogram(z, range=w_range, bins=nbins, density=True)[0] for z in r_shear])
#       8 heights = r.z[5:-15, 0, 0]
# ----> 9 contourf(bin_values, heights, hist_z_100, levels=np.linspace(0, 100))
#      10
#      11 print r.t[0, 0, 600]
#
# /nfs/see-fs-02_users/eeaol/src/canopy/User/lib/python2.7/site-packages/matplotlib/pyplot.pyc in contourf(*args, **kwargs)
#    2648         ax.hold(hold)
#    2649     try:
# -> 2650         ret = ax.contourf(*args, **kwargs)
#    2651         draw_if_interactive()
#    2652     finally:
#
# /nfs/see-fs-02_users/eeaol/src/canopy/User/lib/python2.7/site-packages/matplotlib/axes.pyc in contourf(self, *args, **kwargs)
#    7981             self.cla()
#    7982         kwargs['filled'] = True
# ...

# %%
contourf(r2.t[rs], r2.z[rs], r2.u[rs] * 1000, levels=np.linspace(-70, 70, 100))
cbar = colorbar()
cbar.set_label('streamwise velocity (mm / s)')
xlabel('time after lock release (s)')
ylabel('vertical (mm)')

# %%
contourf(r2c.t[rs], r2c.z[rs], r2c.u[rs] * 1000, levels=np.linspace(-70, 70, 100))
cbar = colorbar()
cbar.set_label('streamwise velocity (mm / s)')
xlabel('time after lock release (s)')
ylabel('vertical (mm)')

# %%
contourf(r2.t[rs], r2.z[rs], r2.w[rs] * 1000, levels=np.linspace(-25, 25, 100))
cbar = colorbar()
cbar.set_label('streamwise velocity (mm / s)')
xlabel('time after lock release (s)')
ylabel('vertical (mm)')

# %%
contourf(r2c.t[rs], r2c.z[rs], r2c.w[rs] * 1000, levels=np.linspace(-25, 25, 100))
cbar = colorbar()
cbar.set_label('streamwise velocity (mm / s)')
xlabel('time after lock release (s)')
ylabel('vertical (mm)')
